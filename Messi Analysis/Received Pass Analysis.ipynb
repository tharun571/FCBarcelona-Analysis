# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Arc
import numpy as np
import math
from matplotlib.patches import Arc
import seaborn as sns

# %%
groundpassstart1 = np.empty((0,2),float)
groundpassend1 = np.empty((0,2),float)
groundpasslength1 = np.array([],dtype=float)
groundpassduration1 = np.array([],dtype=float)
lowpassstart1 = np.empty((0,2),float)
lowpassend1 = np.empty((0,2),float)
lowpasslength1 = np.array([],dtype=float)
lowpassduration1 = np.array([],dtype=float)
highpassstart1 = np.empty((0,2),float)
highpassend1 = np.empty((0,2),float)
highpasslength1 = np.array([],dtype=float)
highpassduration1 = np.array([],dtype=float)

groundpassstart2 = np.empty((0,2),float)
groundpassend2 = np.empty((0,2),float)
groundpasslength2 = np.array([],dtype=float)
groundpassduration2 = np.array([],dtype=float)
lowpassstart2 = np.empty((0,2),float)
lowpassend2 = np.empty((0,2),float)
lowpasslength2 = np.array([],dtype=float)
lowpassduration2 = np.array([],dtype=float)
highpassstart2 = np.empty((0,2),float)
highpassend2 = np.empty((0,2),float)
highpasslength2 = np.array([],dtype=float)
highpassduration2 = np.array([],dtype=float)

groundpassstart3 = np.empty((0,2),float)
groundpassend3 = np.empty((0,2),float)
groundpasslength3 = np.array([],dtype=float)
groundpassduration3 =np.array([],dtype=float)
lowpassstart3 = np.empty((0,2),float)
lowpassend3 = np.empty((0,2),float)
lowpasslength3 = np.array([],dtype=float)
lowpassduration3 = np.array([],dtype=float)
highpassstart3 = np.empty((0,2),float)
highpassend3 = np.empty((0,2),float)
highpasslength3 = np.array([],dtype=float)
highpassduration3 = np.array([],dtype=float)

groundpassstart4 = np.empty((0,2),float)
groundpassend4 = np.empty((0,2),float)
groundpasslength4 =np.array([],dtype=float)
groundpassduration4 = np.array([],dtype=float)
lowpassstart4 = np.empty((0,2),float)
lowpassend4 = np.empty((0,2),float)
lowpasslength4 = np.array([],dtype=float)
lowpassduration4 =np.array([],dtype=float)
highpassstart4 = np.empty((0,2),float)
highpassend4 = np.empty((0,2),float)
highpasslength4 = np.array([],dtype=float)
highpassduration4 = np.array([],dtype=float)

# %%
listt=["1","2","4","21","22","23","24","25","26","27","37","38","39","40","41"]
list1=np.array([])
list2=np.array([])
list3=np.array([])
list4=np.array([])

for a in listt:
    import urllib.request, json
    with urllib.request.urlopen("https://raw.githubusercontent.com/statsbomb/open-data/master/data/matches/11/"+a+".json") as url:
         data = json.loads(url.read().decode())
         for data1 in data:
            n=data1['season']['season_name']
            if n == "2007/2008" or n== "2008/2009" or n== "2009/2010":
                list1=np.append(list1,str(data1['match_id']))
            elif n == "2010/2011" or n== "2011/2012" or n== "2012/2013":
                list2=np.append(list2,str(data1['match_id']))
            elif n == "2013/2014" or n== "2014/2015" or n== "2015/2016":
                list3=np.append(list3,str(data1['match_id']))
            elif n == "2016/2017" or n== "2017/2018" or n== "2018/2019":
                list4=np.append(list4,str(data1['match_id'])) 
                
print(list1.shape)
print(list2.shape)
print(list3.shape)
print(list4.shape)
# Out:
# (94,)
# (102,)
# (102,)
# (104,)

# %%
for a in list1:
        import urllib.request, json
        with urllib.request.urlopen("https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/"+a+".json") as url:
         data = json.loads(url.read().decode())
        for data1 in data:
            ty=data1['type']
            if ty['name'] == 'Pass':
                player=data1['player']
                if player['name'] != 'Lionel Andrés Messi Cuccittini':
                    startx = data1['location'][0]
                    starty = data1['location'][1]
                    pas = data1['pass']
                    if 'recipient' in pas:
                            rec=pas['recipient']
                            if rec['name'] == 'Lionel Andrés Messi Cuccittini':
                                endx = pas['end_location'][0]
                                endy = pas['end_location'][1]
                                startx=endx
                                starty=endy
                                if data1['pass']['height']['name'] == "Ground Pass":
                                    groundpassstart1=np.append(groundpassstart1,np.array([[startx,starty]]),axis=0) 
                                    groundpassend1=np.append(groundpassend1,np.array([[startx,starty]]),axis=0)
                                    groundpasslength1 = np.append(groundpasslength1,pas['length'])
                                    groundpassduration1 = np.append(groundpassduration1,data1['duration'])
                                elif data1['pass']['height']['name'] == "Low Pass":
                                    lowpassstart1=np.append(lowpassstart1,np.array([[startx,starty]]),axis=0) 
                                    lowpassend1=np.append(lowpassend1,np.array([[startx,starty]]),axis=0)
                                    lowpasslength1 = np.append(lowpasslength1,pas['length'])
                                    lowpassduration1 = np.append(lowpassduration1,data1['duration'])
                                else:
                                    highpassstart1=np.append(highpassstart1,np.array([[startx,starty]]),axis=0) 
                                    highpassend1=np.append(highpassend1,np.array([[startx,starty]]),axis=0)
                                    highpasslength1 = np.append(highpasslength1,pas['length'])
                                    highpassduration1 = np.append(highpassduration1,data1['duration'])
                
for a in list2:
        import urllib.request, json
        with urllib.request.urlopen("https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/"+a+".json") as url:
         data = json.loads(url.read().decode())
        for data1 in data:
            ty=data1['type']
            if ty['name'] == 'Pass':
                player=data1['player']
                if player['name'] != 'Lionel Andrés Messi Cuccittini':
                    startx = data1['location'][0]
                    starty = data1['location'][1]
                    pas = data1['pass']
                    if 'recipient' in pas:
                            rec=pas['recipient']
                            if rec['name'] == 'Lionel Andrés Messi Cuccittini':
                                endx = pas['end_location'][0]
                                endy = pas['end_location'][1]
                                startx=endx
                                starty=endy
                                if data1['pass']['height']['name'] == "Ground Pass":
                                    groundpassstart2=np.append(groundpassstart2,np.array([[startx,starty]]),axis=0) 
                                    groundpassend2=np.append(groundpassend2,np.array([[startx,starty]]),axis=0)
                                    groundpasslength2 = np.append(groundpasslength2,pas['length'])
                                    groundpassduration2 = np.append(groundpassduration2,data1['duration'])
                                elif data1['pass']['height']['name'] == "Low Pass":
                                    lowpassstart2=np.append(lowpassstart2,np.array([[startx,starty]]),axis=0) 
                                    lowpassend2=np.append(lowpassend2,np.array([[startx,starty]]),axis=0)
                                    lowpasslength2 = np.append(lowpasslength2,pas['length'])
                                    lowpassduration2 = np.append(lowpassduration2,data1['duration'])
                                else:
                                    highpassstart2=np.append(highpassstart2,np.array([[startx,starty]]),axis=0) 
                                    highpassend2=np.append(highpassend2,np.array([[startx,starty]]),axis=0)
                                    highpasslength2 = np.append(highpasslength2,pas['length'])
                                    highpassduration2 = np.append(highpassduration2,data1['duration'])

for a in list3:
        import urllib.request, json
        with urllib.request.urlopen("https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/"+a+".json") as url:
         data = json.loads(url.read().decode())
        for data1 in data:
            ty=data1['type']
            if ty['name'] == 'Pass':
                player=data1['player']
                if player['name'] != 'Lionel Andrés Messi Cuccittini':
                    startx = data1['location'][0]
                    starty = data1['location'][1]
                    pas = data1['pass']
                    if 'recipient' in pas:
                            rec=pas['recipient']
                            if rec['name'] == 'Lionel Andrés Messi Cuccittini':
                                endx = pas['end_location'][0]
                                endy = pas['end_location'][1]
                                startx=endx
                                starty=endy
                                if data1['pass']['height']['name'] == "Ground Pass":
                                    groundpassstart3=np.append(groundpassstart3,np.array([[startx,starty]]),axis=0) 
                                    groundpassend3=np.append(groundpassend3,np.array([[startx,starty]]),axis=0)
                                    groundpasslength3 = np.append(groundpasslength3,pas['length'])
                                    groundpassduration3 = np.append(groundpassduration3,data1['duration'])
                                elif data1['pass']['height']['name'] == "Low Pass":
                                    lowpassstart3=np.append(lowpassstart3,np.array([[startx,starty]]),axis=0) 
                                    lowpassend3=np.append(lowpassend3,np.array([[startx,starty]]),axis=0)
                                    lowpasslength3 = np.append(lowpasslength3,pas['length'])
                                    lowpassduration3 = np.append(lowpassduration3,data1['duration'])
                                else:
                                    highpassstart3=np.append(highpassstart3,np.array([[startx,starty]]),axis=0) 
                                    highpassend3=np.append(highpassend3,np.array([[startx,starty]]),axis=0)
                                    highpasslength3 = np.append(highpasslength3,pas['length'])
                                    highpassduration3 = np.append(highpassduration3,data1['duration'])
                                            
for a in list4:
        import urllib.request, json
        with urllib.request.urlopen("https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/"+a+".json") as url:
         data = json.loads(url.read().decode())
        for data1 in data:
            ty=data1['type']
            if ty['name'] == 'Pass':
                player=data1['player']
                if player['name'] != 'Lionel Andrés Messi Cuccittini':
                    startx = data1['location'][0]
                    starty = data1['location'][1]
                    pas = data1['pass']
                    if 'recipient' in pas:
                            rec=pas['recipient']
                            if rec['name'] == 'Lionel Andrés Messi Cuccittini':
                                endx = pas['end_location'][0]
                                endy = pas['end_location'][1]
                                startx=endx
                                starty=endy
                                if data1['pass']['height']['name'] == "Ground Pass":
                                    groundpassstart4=np.append(groundpassstart4,np.array([[startx,starty]]),axis=0) 
                                    groundpassend4=np.append(groundpassend4,np.array([[startx,starty]]),axis=0)
                                    groundpasslength4 = np.append(groundpasslength4,pas['length'])
                                    groundpassduration4 = np.append(groundpassduration4,data1['duration'])
                                elif data1['pass']['height']['name'] == "Low Pass":
                                    lowpassstart4=np.append(lowpassstart4,np.array([[startx,starty]]),axis=0) 
                                    lowpassend4=np.append(lowpassend4,np.array([[startx,starty]]),axis=0)
                                    lowpasslength4 = np.append(lowpasslength4,pas['length'])
                                    lowpassduration4 = np.append(lowpassduration4,data1['duration'])
                                else:
                                    highpassstart4=np.append(highpassstart4,np.array([[startx,starty]]),axis=0) 
                                    highpassend4=np.append(highpassend4,np.array([[startx,starty]]),axis=0)
                                    highpasslength4 = np.append(highpasslength4,pas['length'])
                                    highpassduration4 = np.append(highpassduration4,data1['duration'])

# %%
lengthground=np.array([np.average(groundpasslength1),np.average(groundpasslength2),np.average(groundpasslength3),np.average(groundpasslength4)])
durground=np.array([np.average(groundpassduration1),np.average(groundpassduration2),np.average(groundpassduration3),np.average(groundpassduration4)])
lengthlow=np.array([np.average(lowpasslength1),np.average(lowpasslength2),np.average(lowpasslength3),np.average(lowpasslength4)])
durlow=np.array([np.average(lowpassduration1),np.average(lowpassduration2),np.average(lowpassduration3),np.average(lowpassduration4)])
lengthhigh=np.array([np.average(highpasslength1),np.average(highpasslength2),np.average(highpasslength3),np.average(highpasslength4)])
durhigh=np.array([np.average(highpassduration1),np.average(highpassduration2),np.average(highpassduration3),np.average(highpassduration4)])

# %%
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)
    #Pitch Outline & Centre Lin
    plt.plot([0,0],[0,90], color="black")
    plt.plot([0,130],[90,90], color="black")
    plt.plot([130,130],[90,0], color="black")
    plt.plot([130,0],[0,0], color="black")
    plt.plot([65,65],[0,90], color="black")
    
    #Left Penalty Area
    plt.plot([16.5,16.5],[65,25],color="black")
    plt.plot([0,16.5],[65,65],color="black")
    plt.plot([16.5,0],[25,25],color="black")
    
    #Right Penalty Area
    plt.plot([130,113.5],[65,65],color="black")
    plt.plot([113.5,113.5],[65,25],color="black")
    plt.plot([113.5,130],[25,25],color="black")
    
    #Left 6-yard Box
    plt.plot([0,5.5],[54,54],color="black")
    plt.plot([5.5,5.5],[54,36],color="black")
    plt.plot([5.5,0.5],[36,36],color="black")
    
    #Right 6-yard Box
    plt.plot([130,124.5],[54,54],color="black")
    plt.plot([124.5,124.5],[54,36],color="black")
    plt.plot([124.5,130],[36,36],color="black")
    
    #Prepare Circles
    centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
    centreSpot = plt.Circle((65,45),0.8,color="black")
    leftPenSpot = plt.Circle((11,45),0.8,color="black")
    rightPenSpot = plt.Circle((119,45),0.8,color="black")
    
    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)
    ax.add_patch(rightPenSpot)
    
    #Prepare Arcs
    leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
    rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

    #Draw Arcs
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)
    
    sns.kdeplot(groundpassstart1[:,0],groundpassstart1[:,1], shade="True", n_levels=40)
    sns.kdeplot(lowpassstart1[:,0],lowpassstart1[:,1], shade="True", n_levels=40)
    sns.kdeplot(highpassstart1[:,0],highpassstart1[:,1], shade="True", n_levels=40)
    
    #Tidy Axes
   
   
    fig.set_size_inches(10,7)
    plt.ylim(0, 90)
    plt.xlim(0, 130)
    
    ax.set_title("Recieved Passes of Seasons 07/08, 08/09, 09/10")
    
    
    #Display Pitch
    plt.show()

# %%
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)
    #Pitch Outline & Centre Lin
    plt.plot([0,0],[0,90], color="black")
    plt.plot([0,130],[90,90], color="black")
    plt.plot([130,130],[90,0], color="black")
    plt.plot([130,0],[0,0], color="black")
    plt.plot([65,65],[0,90], color="black")
    
    #Left Penalty Area
    plt.plot([16.5,16.5],[65,25],color="black")
    plt.plot([0,16.5],[65,65],color="black")
    plt.plot([16.5,0],[25,25],color="black")
    
    #Right Penalty Area
    plt.plot([130,113.5],[65,65],color="black")
    plt.plot([113.5,113.5],[65,25],color="black")
    plt.plot([113.5,130],[25,25],color="black")
    
    #Left 6-yard Box
    plt.plot([0,5.5],[54,54],color="black")
    plt.plot([5.5,5.5],[54,36],color="black")
    plt.plot([5.5,0.5],[36,36],color="black")
    
    #Right 6-yard Box
    plt.plot([130,124.5],[54,54],color="black")
    plt.plot([124.5,124.5],[54,36],color="black")
    plt.plot([124.5,130],[36,36],color="black")
    
    #Prepare Circles
    centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
    centreSpot = plt.Circle((65,45),0.8,color="black")
    leftPenSpot = plt.Circle((11,45),0.8,color="black")
    rightPenSpot = plt.Circle((119,45),0.8,color="black")
    
    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)
    ax.add_patch(rightPenSpot)
    
    #Prepare Arcs
    leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
    rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

    #Draw Arcs
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)
    
     
    sns.kdeplot(groundpassstart2[:,0],groundpassstart2[:,1], shade="True", n_levels=40)
    sns.kdeplot(lowpassstart2[:,0],lowpassstart2[:,1], shade="True", n_levels=40)
    sns.kdeplot(highpassstart2[:,0],highpassstart2[:,1], shade="True", n_levels=40)
    
    #Tidy Axes
   
   
    fig.set_size_inches(10,7)
    plt.ylim(0, 90)
    plt.xlim(0, 130)
    
    ax.set_title("Recieved Passes of Seasons 10/11, 11/12, 12/13")
    
    
    #Display Pitch
    plt.show()

# %%
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)
    #Pitch Outline & Centre Lin
    plt.plot([0,0],[0,90], color="black")
    plt.plot([0,130],[90,90], color="black")
    plt.plot([130,130],[90,0], color="black")
    plt.plot([130,0],[0,0], color="black")
    plt.plot([65,65],[0,90], color="black")
    
    #Left Penalty Area
    plt.plot([16.5,16.5],[65,25],color="black")
    plt.plot([0,16.5],[65,65],color="black")
    plt.plot([16.5,0],[25,25],color="black")
    
    #Right Penalty Area
    plt.plot([130,113.5],[65,65],color="black")
    plt.plot([113.5,113.5],[65,25],color="black")
    plt.plot([113.5,130],[25,25],color="black")
    
    #Left 6-yard Box
    plt.plot([0,5.5],[54,54],color="black")
    plt.plot([5.5,5.5],[54,36],color="black")
    plt.plot([5.5,0.5],[36,36],color="black")
    
    #Right 6-yard Box
    plt.plot([130,124.5],[54,54],color="black")
    plt.plot([124.5,124.5],[54,36],color="black")
    plt.plot([124.5,130],[36,36],color="black")
    
    #Prepare Circles
    centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
    centreSpot = plt.Circle((65,45),0.8,color="black")
    leftPenSpot = plt.Circle((11,45),0.8,color="black")
    rightPenSpot = plt.Circle((119,45),0.8,color="black")
    
    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)
    ax.add_patch(rightPenSpot)
    
    #Prepare Arcs
    leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
    rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

    #Draw Arcs
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)
    
     
    sns.kdeplot(groundpassstart3[:,0],groundpassstart3[:,1], shade="True", n_levels=40)
    sns.kdeplot(lowpassstart3[:,0],lowpassstart3[:,1], shade="True", n_levels=40)
    sns.kdeplot(highpassstart3[:,0],highpassstart3[:,1], shade="True", n_levels=40)
    
    #Tidy Axes
   
   
    fig.set_size_inches(10,7)
    plt.ylim(0, 90)
    plt.xlim(0, 130)
    
    ax.set_title("Recieved Passes of Seasons 13/14, 14/15, 15/16")
    
    
    #Display Pitch
    plt.show()

# %%
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)
    #Pitch Outline & Centre Lin
    plt.plot([0,0],[0,90], color="black")
    plt.plot([0,130],[90,90], color="black")
    plt.plot([130,130],[90,0], color="black")
    plt.plot([130,0],[0,0], color="black")
    plt.plot([65,65],[0,90], color="black")
    
    #Left Penalty Area
    plt.plot([16.5,16.5],[65,25],color="black")
    plt.plot([0,16.5],[65,65],color="black")
    plt.plot([16.5,0],[25,25],color="black")
    
    #Right Penalty Area
    plt.plot([130,113.5],[65,65],color="black")
    plt.plot([113.5,113.5],[65,25],color="black")
    plt.plot([113.5,130],[25,25],color="black")
    
    #Left 6-yard Box
    plt.plot([0,5.5],[54,54],color="black")
    plt.plot([5.5,5.5],[54,36],color="black")
    plt.plot([5.5,0.5],[36,36],color="black")
    
    #Right 6-yard Box
    plt.plot([130,124.5],[54,54],color="black")
    plt.plot([124.5,124.5],[54,36],color="black")
    plt.plot([124.5,130],[36,36],color="black")
    
    #Prepare Circles
    centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
    centreSpot = plt.Circle((65,45),0.8,color="black")
    leftPenSpot = plt.Circle((11,45),0.8,color="black")
    rightPenSpot = plt.Circle((119,45),0.8,color="black")
    
    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)
    ax.add_patch(rightPenSpot)
    
    #Prepare Arcs
    leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
    rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

    #Draw Arcs
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)
    
     
    sns.kdeplot(groundpassstart4[:,0],groundpassstart4[:,1], shade="True", n_levels=40)
    sns.kdeplot(lowpassstart4[:,0],lowpassstart4[:,1], shade="True", n_levels=40)
    sns.kdeplot(highpassstart4[:,0],highpassstart4[:,1], shade="True", n_levels=40)
    
    #Tidy Axes
   
   
    fig.set_size_inches(10,7)
    plt.ylim(0, 90)
    plt.xlim(0, 130)
    
    ax.set_title("Recieved Seasons 16/17, 17/18, 18/19")
    
    
    #Display Pitch
    plt.show()

# %%
yr=np.array(["07/08 - 09/10","10/11 - 12/13","13/14 - 15/16","16/17 - 18,19"])
fig, ax = plt.subplots()

#Set plot size
fig.set_size_inches(7, 5)

plt.plot(yr,lengthground,"o")
plt.plot(yr,lengthlow,"o")
plt.plot(yr,lengthhigh,"o")
ax.set_xlabel("Season")
ax.set_ylabel("Average Length of Recieved High Pass, Low Pass, Ground Pass")
# Out:
# Text(0, 0.5, 'Average Length of Recieved High Pass, Low Pass, Ground Pass')

# %%
yr=np.array(["07/08 - 09/10","10/11 - 12/13","13/14 - 15/16","16/17 - 18,19"])
fig, ax = plt.subplots()

#Set plot size
fig.set_size_inches(7, 5)

plt.plot(yr,(lengthground+lengthlow+lengthhigh)/3,"o")

ax.set_xlabel("Season")
ax.set_ylabel("Average Length of All Recieved Passes")
# Out:
# Text(0, 0.5, 'Average Length of All Recieved Passes')

# %%
yr=np.array(["07/08 - 09/10","10/11 - 12/13","13/14 - 15/16","16/17 - 18,19"])
fig, ax = plt.subplots()

#Set plot size
fig.set_size_inches(7, 5)

plt.plot(yr,durground,"o")
plt.plot(yr,durlow,"o")
plt.plot(yr,durhigh,"o")
ax.set_xlabel("Season")
ax.set_ylabel("Average Duration of Recieved High Pass, Low Pass, Ground Pass")
# Out:
# Text(0, 0.5, 'Average Duration of Recieved High Pass, Low Pass, Ground Pass')

# %%
yr=np.array(["07/08 - 09/10","10/11 - 12/13","13/14 - 15/16","16/17 - 18,19"])
fig, ax = plt.subplots()

#Set plot size
fig.set_size_inches(7, 5)

plt.plot(yr,(durground+durlow+durhigh)/3,"o")
ax.set_xlabel("Season")
ax.set_ylabel("Average Duration of All Recieved Passes")
# Out:
# Text(0, 0.5, 'Average Duration of All Recieved Passes')

# %%
total=np.array([groundpassstart1.size+lowpassstart1.size+highpassstart1.size,groundpassstart2.size+lowpassstart2.size+highpassstart2.size,groundpassstart3.size+lowpassstart3.size+highpassstart3.size,groundpassstart4.size+lowpassstart4.size+highpassstart4.size])

# %%
yr=np.array(["07/08 - 09/10","10/11 - 12/13","13/14 - 15/16","16/17 - 18,19"])
fig, ax = plt.subplots()

#Set plot size
fig.set_size_inches(7, 5)

plt.plot(yr,total,"o")
ax.set_xlabel("Season")
ax.set_ylabel("Number of Recieved passes per season")
# Out:
# Text(0, 0.5, 'Number of Recieved passes per season')

# %%
total1=np.array([groundpassstart1.size,groundpassstart2.size,groundpassstart3.size,groundpassstart4.size])
total2=np.array([lowpassstart1.size,lowpassstart2.size,lowpassstart3.size,lowpassstart4.size])
total3=np.array([highpassstart1.size,highpassstart2.size,highpassstart3.size,highpassstart4.size])

yr=np.array(["07/08 - 09/10","10/11 - 12/13","13/14 - 15/16","16/17 - 18,19"])
fig, ax = plt.subplots()

#Set plot size
fig.set_size_inches(7, 5)

plt.plot(yr,total1,"o")
plt.plot(yr,total2,"o")
plt.plot(yr,total3,"o")
ax.set_xlabel("Season")
ax.set_ylabel("Number of Recieved High Pass, Low Pass, Ground Pass")
# Out:
# Text(0, 0.5, 'Number of Recieved High Pass, Low Pass, Ground Pass')
