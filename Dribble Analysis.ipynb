# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Arc
import numpy as np
match_id="18236"
import math
from matplotlib.patches import Arc
import seaborn as sns

# %%
  
    heat=np.zeros((130,90),dtype=float)
    heat1=np.empty((0,2),int)
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)
    
    for a in list11:
        import urllib.request, json
        with urllib.request.urlopen("https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/"+a+".json") as url:
         data = json.loads(url.read().decode())
        for data1 in data:
            ty=data1['type']
            if ty['name'] == 'Dribble':
                player=data1['player']
                if data1['player']['name'] == 'Lionel Andrés Messi Cuccittini':
                        startx = data1['location'][0]
                        starty = data1['location'][1]
                        if data1['dribble']['outcome']['name'] != 'Incomplete':
                             heat[math.floor(startx)][math.floor(starty)]=heat[math.floor(startx)][math.floor(starty)]+1
                             heat1=np.append(heat1,np.array([[startx,starty]]),axis=0)  
    #Pitch Outline & Centre Line
    plt.plot([0,0],[0,90], color="black")
    plt.plot([0,130],[90,90], color="black")
    plt.plot([130,130],[90,0], color="black")
    plt.plot([130,0],[0,0], color="black")
    plt.plot([65,65],[0,90], color="black")
    
    #Left Penalty Area
    plt.plot([16.5,16.5],[65,25],color="black")
    plt.plot([0,16.5],[65,65],color="black")
    plt.plot([16.5,0],[25,25],color="black")
    
    #Right Penalty Area
    plt.plot([130,113.5],[65,65],color="black")
    plt.plot([113.5,113.5],[65,25],color="black")
    plt.plot([113.5,130],[25,25],color="black")
    
    #Left 6-yard Box
    plt.plot([0,5.5],[54,54],color="black")
    plt.plot([5.5,5.5],[54,36],color="black")
    plt.plot([5.5,0.5],[36,36],color="black")
    
    #Right 6-yard Box
    plt.plot([130,124.5],[54,54],color="black")
    plt.plot([124.5,124.5],[54,36],color="black")
    plt.plot([124.5,130],[36,36],color="black")
    
    #Prepare Circles
    centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
    centreSpot = plt.Circle((65,45),0.8,color="black")
    leftPenSpot = plt.Circle((11,45),0.8,color="black")
    rightPenSpot = plt.Circle((119,45),0.8,color="black")
    
    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)
    ax.add_patch(rightPenSpot)
    
    #Prepare Arcs
    leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
    rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

    #Draw Arcs
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)
    
    sns.kdeplot(heat1[:,0],heat1[:,1], shade="True", n_levels=40)
    plt.ylim(0, 90)
    plt.xlim(0, 130)
    
    ax.set_title("Season 07/08, 08/09, 09/10")
    
   
    
    
    #Display Pitch
    plt.show()

# %%
    heat=np.zeros((130,90),dtype=int)
    heat1=np.empty((0,2),float)
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)
    
    for a in list2:
        import urllib.request, json
        with urllib.request.urlopen("https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/"+a+".json") as url:
         data = json.loads(url.read().decode())
        for data1 in data:
            ty=data1['type']
            if ty['name'] == 'Dribble':
                player=data1['player']
                if data1['player']['name'] == 'Lionel Andrés Messi Cuccittini':
                        startx = data1['location'][0]
                        starty = data1['location'][1]
                        if data1['dribble']['outcome']['name'] != 'Incomplete':
                            heat1=np.append(heat1,np.array([[startx,starty]]),axis=0)  
    #Pitch Outline & Centre Lin
    plt.plot([0,0],[0,90], color="black")
    plt.plot([0,130],[90,90], color="black")
    plt.plot([130,130],[90,0], color="black")
    plt.plot([130,0],[0,0], color="black")
    plt.plot([65,65],[0,90], color="black")
    
    #Left Penalty Area
    plt.plot([16.5,16.5],[65,25],color="black")
    plt.plot([0,16.5],[65,65],color="black")
    plt.plot([16.5,0],[25,25],color="black")
    
    #Right Penalty Area
    plt.plot([130,113.5],[65,65],color="black")
    plt.plot([113.5,113.5],[65,25],color="black")
    plt.plot([113.5,130],[25,25],color="black")
    
    #Left 6-yard Box
    plt.plot([0,5.5],[54,54],color="black")
    plt.plot([5.5,5.5],[54,36],color="black")
    plt.plot([5.5,0.5],[36,36],color="black")
    
    #Right 6-yard Box
    plt.plot([130,124.5],[54,54],color="black")
    plt.plot([124.5,124.5],[54,36],color="black")
    plt.plot([124.5,130],[36,36],color="black")
    
    #Prepare Circles
    centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
    centreSpot = plt.Circle((65,45),0.8,color="black")
    leftPenSpot = plt.Circle((11,45),0.8,color="black")
    rightPenSpot = plt.Circle((119,45),0.8,color="black")
    
    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)
    ax.add_patch(rightPenSpot)
    
    #Prepare Arcs
    leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
    rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

    #Draw Arcs
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)
    
    sns.kdeplot(heat1[:,0],heat1[:,1], shade="True", n_levels=40)
    
    #Tidy Axes
   
   
    fig.set_size_inches(7,5)
    plt.ylim(0, 90)
    plt.xlim(0, 130)
    
    ax.set_title("Season 10/11, 11/12, 12/13")
    
    #Display Pitch
    plt.show()

# %%
    heat=np.zeros((130,90),dtype=int)
    heat1=np.empty((0,2),float)
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)
    
    for a in list4:
        import urllib.request, json
        with urllib.request.urlopen("https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/"+a+".json") as url:
         data = json.loads(url.read().decode())
        for data1 in data:
            ty=data1['type']
            if ty['name'] == 'Dribble':
                player=data1['player']
                if data1['player']['name'] == 'Lionel Andrés Messi Cuccittini':
                        startx = data1['location'][0]
                        starty = data1['location'][1]
                        if data1['dribble']['outcome']['name'] != 'Incomplete':
                            heat1=np.append(heat1,np.array([[startx,starty]]),axis=0)  
    #Pitch Outline & Centre Lin
    plt.plot([0,0],[0,90], color="black")
    plt.plot([0,130],[90,90], color="black")
    plt.plot([130,130],[90,0], color="black")
    plt.plot([130,0],[0,0], color="black")
    plt.plot([65,65],[0,90], color="black")
    
    #Left Penalty Area
    plt.plot([16.5,16.5],[65,25],color="black")
    plt.plot([0,16.5],[65,65],color="black")
    plt.plot([16.5,0],[25,25],color="black")
    
    #Right Penalty Area
    plt.plot([130,113.5],[65,65],color="black")
    plt.plot([113.5,113.5],[65,25],color="black")
    plt.plot([113.5,130],[25,25],color="black")
    
    #Left 6-yard Box
    plt.plot([0,5.5],[54,54],color="black")
    plt.plot([5.5,5.5],[54,36],color="black")
    plt.plot([5.5,0.5],[36,36],color="black")
    
    #Right 6-yard Box
    plt.plot([130,124.5],[54,54],color="black")
    plt.plot([124.5,124.5],[54,36],color="black")
    plt.plot([124.5,130],[36,36],color="black")
    
    #Prepare Circles
    centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
    centreSpot = plt.Circle((65,45),0.8,color="black")
    leftPenSpot = plt.Circle((11,45),0.8,color="black")
    rightPenSpot = plt.Circle((119,45),0.8,color="black")
    
    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)
    ax.add_patch(rightPenSpot)
    
    #Prepare Arcs
    leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
    rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

    #Draw Arcs
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)
    
    sns.kdeplot(heat1[:,0],heat1[:,1], shade="True", n_levels=40)
    
    #Tidy Axes
   
   
    fig.set_size_inches(7,5)
    plt.ylim(0, 90)
    plt.xlim(0, 130)
    
    ax.set_title("Season 16/17, 17/18, 18/19")
    
    
    #Display Pitch
    plt.show()

# %%
    heat=np.zeros((130,90),dtype=int)
    heat1=np.empty((0,2),float)
    fig=plt.figure()
    ax=fig.add_subplot(1,1,1)
    
    for a in list3:
        import urllib.request, json
        with urllib.request.urlopen("https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/"+a+".json") as url:
         data = json.loads(url.read().decode())
        for data1 in data:
            ty=data1['type']
            if ty['name'] == 'Dribble':
                player=data1['player']
                if data1['player']['name'] == 'Lionel Andrés Messi Cuccittini':
                        startx = data1['location'][0]
                        starty = data1['location'][1]
                        if data1['dribble']['outcome']['name'] != 'Incomplete':
                            heat1=np.append(heat1,np.array([[startx,starty]]),axis=0)  
    #Pitch Outline & Centre Lin
    plt.plot([0,0],[0,90], color="black")
    plt.plot([0,130],[90,90], color="black")
    plt.plot([130,130],[90,0], color="black")
    plt.plot([130,0],[0,0], color="black")
    plt.plot([65,65],[0,90], color="black")
    
    #Left Penalty Area
    plt.plot([16.5,16.5],[65,25],color="black")
    plt.plot([0,16.5],[65,65],color="black")
    plt.plot([16.5,0],[25,25],color="black")
    
    #Right Penalty Area
    plt.plot([130,113.5],[65,65],color="black")
    plt.plot([113.5,113.5],[65,25],color="black")
    plt.plot([113.5,130],[25,25],color="black")
    
    #Left 6-yard Box
    plt.plot([0,5.5],[54,54],color="black")
    plt.plot([5.5,5.5],[54,36],color="black")
    plt.plot([5.5,0.5],[36,36],color="black")
    
    #Right 6-yard Box
    plt.plot([130,124.5],[54,54],color="black")
    plt.plot([124.5,124.5],[54,36],color="black")
    plt.plot([124.5,130],[36,36],color="black")
    
    #Prepare Circles
    centreCircle = plt.Circle((65,45),9.15,color="black",fill=False)
    centreSpot = plt.Circle((65,45),0.8,color="black")
    leftPenSpot = plt.Circle((11,45),0.8,color="black")
    rightPenSpot = plt.Circle((119,45),0.8,color="black")
    
    #Draw Circles
    ax.add_patch(centreCircle)
    ax.add_patch(centreSpot)
    ax.add_patch(leftPenSpot)
    ax.add_patch(rightPenSpot)
    
    #Prepare Arcs
    leftArc = Arc((11,45),height=18.3,width=18.3,angle=0,theta1=310,theta2=50,color="black")
    rightArc = Arc((119,45),height=18.3,width=18.3,angle=0,theta1=130,theta2=230,color="black")

    #Draw Arcs
    ax.add_patch(leftArc)
    ax.add_patch(rightArc)
    
    sns.kdeplot(heat1[:,0],heat1[:,1], shade="True", n_levels=40)
    
    #Tidy Axes
   
   
    fig.set_size_inches(7,5)
    plt.ylim(0, 90)
    plt.xlim(0, 130)
    
    ax.set_title("Season 13/14, 14/15, 15/16")
    
    
    #Display Pitch
    plt.show()

# %%
s1=0
s2=0
for a in list11:
        import urllib.request, json
        with urllib.request.urlopen("https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/"+a+".json") as url:
         data = json.loads(url.read().decode())
        for data1 in data:
            ty=data1['type']
            if ty['name'] == 'Dribble':
                player=data1['player']
                if data1['player']['name'] == 'Lionel Andrés Messi Cuccittini':
                        s1=s1+1
                        if data1['dribble']['outcome']['name'] != 'Incomplete':
                            s2=s2+1
print(s1)
print(s2)
# Out:
# 890
# 634

# %%
s1=0
s2=0
for a in list2:
        import urllib.request, json
        with urllib.request.urlopen("https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/"+a+".json") as url:
         data = json.loads(url.read().decode())
        for data1 in data:
            ty=data1['type']
            if ty['name'] == 'Dribble':
                player=data1['player']
                if data1['player']['name'] == 'Lionel Andrés Messi Cuccittini':
                        s1=s1+1
                        if data1['dribble']['outcome']['name'] != 'Incomplete':
                            s2=s2+1
print(s1)
print(s2)
# Out:
# 982
# 672

# %%
s1=0
s2=0
for a in list3:
        import urllib.request, json
        with urllib.request.urlopen("https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/"+a+".json") as url:
         data = json.loads(url.read().decode())
        for data1 in data:
            ty=data1['type']
            if ty['name'] == 'Dribble':
                player=data1['player']
                if data1['player']['name'] == 'Lionel Andrés Messi Cuccittini':
                        s1=s1+1
                        if data1['dribble']['outcome']['name'] != 'Incomplete':
                            s2=s2+1
print(s1)
print(s2)
# Out:
# 854
# 600

# %%
s1=0
s2=0
for a in list4:
        import urllib.request, json
        with urllib.request.urlopen("https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/"+a+".json") as url:
         data = json.loads(url.read().decode())
        for data1 in data:
            ty=data1['type']
            if ty['name'] == 'Dribble':
                player=data1['player']
                if data1['player']['name'] == 'Lionel Andrés Messi Cuccittini':
                        s1=s1+1
                        if data1['dribble']['outcome']['name'] != 'Incomplete':
                            s2=s2+1
print(s1)
print(s2)
# Out:
# 748
# 508

# %%
yr=np.array(["07/08 - 09/10","10/11 - 12/13","13/14 - 15/16","16/17 - 18,19"])
dr=np.array([890,982,854,748])
drs=np.array([634,672,600,508])
per=np.array([71.23,68.43,70.25,67.91])
fig, ax = plt.subplots()

#Set plot size
fig.set_size_inches(7, 5)

plt.plot(yr,dr,"o")
ax.set_xlabel("Season")
ax.set_ylabel("Number of Dribbles")
# Out:
# Text(0, 0.5, 'Number of Dribbles')

# %%
fig, ax = plt.subplots()

#Set plot size
fig.set_size_inches(7, 5)

plt.plot(yr,drs,"o")

ax.set_xlabel("Season")
ax.set_ylabel("Number of Succesful Dribbles")
# Out:
# Text(0, 0.5, 'Number of Succesful Dribbles')

# %%
fig, ax = plt.subplots()

#Set plot size
fig.set_size_inches(7, 5)

plt.plot(yr,per,"o")
ax.set_xlabel("Season")
ax.set_ylabel("Successfull Dribble Percentage")
# Out:
# Text(0, 0.5, 'Successfull Dribble Percentage')

# %%
with urllib.request.urlopen("https://raw.githubusercontent.com/statsbomb/open-data/master/data/events/"+match_id+".json") as url:
         data = json.loads(url.read().decode())
         for data1 in data:
            ty=data1['type']
            if ty['name'] == 'Dribble':
                player=data1['player']
                if data1['player']['name'] == 'Lionel Andrés Messi Cuccittini':
                        s1=s1+1
                        if data1['dribble']['outcome']['name'] != 'Incomplete':
                            print(data1)
# Out:
# {'id': 'b1f5ef5c-8e7d-4fa2-8de6-032a818ce253', 'index': 567, 'period': 1, 'timestamp': '00:11:06.911', 'minute': 11, 'second': 6, 'type': {'id': 14, 'name': 'Dribble'}, 'possession': 29, 'possession_team': {'id': 217, 'name': 'Barcelona'}, 'play_pattern': {'id': 2, 'name': 'From Corner'}, 'team': {'id': 217, 'name': 'Barcelona'}, 'player': {'id': 5503, 'name': 'Lionel Andrés Messi Cuccittini'}, 'position': {'id': 23, 'name': 'Center Forward'}, 'location': [103.0, 13.0], 'duration': 0.0, 'under_pressure': True, 'related_events': ['555ba14c-10a7-4506-822e-a624036776b4'], 'dribble': {'outcome': {'id': 8, 'name': 'Complete'}}}
# ...
